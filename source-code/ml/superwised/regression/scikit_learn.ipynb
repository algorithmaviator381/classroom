# %%
#data manipulation and visualisations libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/AISSMS.csv')

# %%
# Step 2: Display the first few rows of the dataset to get an overview
print(df.head())
# Out:
#    Working Hours  Salary  Working ENV  Growth Opportunities  \
# 0             17      21            6                    13
# 1              6      12            3                    13
# 2             12      16           10                    12
# 3             19      14            8                    12
# 4             17       3            7                    15
#
#    Satisfaction Rate  Burnout Rate
# 0                 88        84.693
# 1                 85        68.647
# 2                 46        53.728
# 3                 88        81.759
# 4                 16        30.869

# %%
# Step 3: Summary statistics of the numerical columns
print(df.describe())
# Out:
#        Working Hours       Salary  Working ENV  Growth Opportunities  \
# count    1000.000000  1000.000000  1000.000000           1000.000000
# mean       12.851000    12.844000     5.587000             14.005000
# std         6.954219     7.225501     2.848604              1.401049
# min         1.000000     1.000000     1.000000             12.000000
# 25%         7.000000     7.000000     3.000000             13.000000
# 50%        13.000000    12.000000     6.000000             14.000000
# 75%        19.000000    19.000000     8.000000             15.000000
# max        24.000000    25.000000    10.000000             16.000000
#
#        Satisfaction Rate  Burnout Rate
# count        1000.000000   1000.000000
# mean           50.931000     54.587194
# std            29.638196     18.857064
# min             1.000000     15.664000
# 25%            25.000000     39.126750
# 50%            52.000000     54.437500
# 75%            78.000000     70.004250
# ...

# %%
# Step 4: Check for missing values
print(df.isnull().sum())
# Out:
# Working Hours           0
# Salary                  0
# Working ENV             0
# Growth Opportunities    0
# Satisfaction Rate       0
# Burnout Rate            0
# dtype: int64

# %%
# Step 5: Correlation matrix and heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns), correlation_matrix.columns))
plt.yticks(range(len(correlation_matrix.columns), correlation_matrix.columns))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\pradi\OneDrive\Desktop\classroom\ml\superwised\regression\scikit_learn.ipynb Cell 6 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/pradi/OneDrive/Desktop/classroom/ml/superwised/regression/scikit_learn.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='none')
#       <a href='vscode-notebook-cell:/c%3A/Users/pradi/OneDrive/Desktop/classroom/ml/superwised/regression/scikit_learn.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> plt.colorbar()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pradi/OneDrive/Desktop/classroom/ml/superwised/regression/scikit_learn.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> plt.xticks(range(len(correlation_matrix.columns), correlation_matrix.columns))
# ...

# %%
# Step 6: Histograms and box plots for numerical variables
plt.figure(figsize=(12, 6))
for i, column in enumerate(df.columns):
    plt.subplot(2, 3, i+1)
    plt.hist(df[column], bins=20)
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
# Step 7: Scatter plots for relationships between variables
plt.figure(figsize=(12, 6))
for i, column in enumerate(df.columns[:-1]):  # Exclude the dependent variable (Burnout Rate)
    plt.subplot(2, 2, i+1)
    plt.scatter(df[column], df['Burnout Rate'])
    plt.xlabel(column)
    plt.ylabel('Burnout Rate')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\pradi\OneDrive\Desktop\classroom\ml\superwised\regression\scikit_learn.ipynb Cell 8 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/pradi/OneDrive/Desktop/classroom/ml/superwised/regression/scikit_learn.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(12, 6))
#       <a href='vscode-notebook-cell:/c%3A/Users/pradi/OneDrive/Desktop/classroom/ml/superwised/regression/scikit_learn.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> for i, column in enumerate(df.columns[:-1]):  # Exclude the dependent variable (Burnout Rate)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pradi/OneDrive/Desktop/classroom/ml/superwised/regression/scikit_learn.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     plt.subplot(2, 2, i+1)
# ...
